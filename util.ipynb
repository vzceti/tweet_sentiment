# %% [markdown]
# Driver file to run other files (pipeline) - this should be the only file you run!

# %%
# Number of tweets to pull
max_count = 500

# Basic UI so I don't have to use terminal
import tkinter as tk
from tkinter import simpledialog

ROOT = tk.Tk()
ROOT.withdraw()
frame_a = tk.Frame()
frame_b = tk.Frame()

# Phrase to set
hashtag_phrase = simpledialog.askstring(title="Test",
                                  prompt="Enter hashtag phrase")
tk.Button(frame_b, text="Quit", command=ROOT.destroy)
# Out:
# <tkinter.Button object .!frame8.!button>

# %%
# Commands to run the exploratory data analysis file, the twitter connect file, 
# and the sentiment analysis (model training, testing, and implementation) file
# %run ./eda.ipynb
# %run ./twitter_connect.ipynb
# %run ./sentiment_analysis.ipynb
# %run ./post_eda.ipynb
# Out:
# weighted: 478.40916477117963
# unweighted: 180.11552891410412
# average weighted: 0.9568183295423592
# average unweighted 0.36023105782820825
